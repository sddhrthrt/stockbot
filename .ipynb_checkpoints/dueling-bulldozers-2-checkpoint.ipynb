# %%
from bidder import *
import websocket
import json
account = "TLB99029472"
venue = "NUEX"
stock = "NTU"
header['X-Starfighter-Authorization'] = "c8bbc206d27988125aa25e396f2f290f22109dbe"

import functools
import random

# %%
amount, position = 0, 0
avgask, avgbid = guess_price(venue, stock)
curask, curbid = 0, 0

# %%
amount, position, avgask, avgbid = (-1120005, 200, 5005, 4902)


curask, curbid = (0, 0)

# %%
amount, position, avgask, avgbid
# Out:
# (-1120005, 200, 5005, 4902)

# %%
navs, nav_news, sell_orders, buy_orders = [[0]*200]*4

# %%
def quote_listener(account, ws, message):
    global amount, position, avgask, avgbid, curask, curbid, navs, nav_news, sell_orders, buy_orders
    quote = json.loads(message).get('quote', None)
    if quote is None:
        return
    myrate = abs(amount/position) if not position == 0 else 0 if not amount == 0 else avgask
    navs = navs[1:] + [amount + position * curbid]
    
    buy_orders = buy_orders[1:] + [buy_orders[-1]]
    if position < 200:
        if 'ask' in quote:
            curask = quote['ask']
            #anamoly, avgasksize = check_anamoly(avgasksize, quote['ask'])
            if quote['ask'] < myrate - 400:
                size = quote['askSize'] if (position + quote['askSize']) < 200 else 200 - position
                res = buy(account, venue, stock, quote['ask']+200, size, 'immediate-or-cancel')
                buy_oders[-1] = amount - size*(quote['ask']+200) + (position+size)*curbid
                if res['ok']:
                    amount -= res['totalFilled'] * res['price']
                    position += res['totalFilled']
                    print res['originalQty'], '/', res['totalFilled']
                else:
                    print res
        
    myrate = abs(amount/position) if not position == 0 else 0 if not amount == 0 else avgbid

    sell_orders = sell_orders[1:] + [sell_orders[-1]]
    if position > -200:
        if 'bid' in quote:
            curbid = quote['bid']
            #anamoly, avgbidsize = check_anamoly(avgbidsize, quote['bid'])
            if quote['bid'] > myrate + 400:
                size = quote['bidSize'] if (position - quote['bidSize']) > -200 else 200 + position
                res = sell(account, venue, stock, quote['bid']-200, size, 'immediate-or-cancel')
                sell_orders[-1] = amount + (quote['bid']-200)*size + (position-size)*curbid
                if res['ok']:
                    amount += res['totalFilled'] * res['price']
                    position -= res['totalFilled']
                    print res['originalQty'], '/', res['totalFilled']
                else:
                    print res
    
    if position > 200:
        if 'bid' in quote:
            if quote['bid'] > myrate + 1000:
                res = sell(account, venue, stock, quote['bid']-100, position-100, 'immediate-or-cancel')
                if res['ok']:
                    amount += res['totalFilled'] * res['price']
                    position -= res['totalfilled']
                print res
    nav_news = nav_news[1:] + [amount + position * curbid]

# %%
quote_websocket(account, venue, stock, functools.partial(quote_listener, account))
# Out:
# <Thread(Thread-3, started daemon 140213185521408)>
# DEBUG:root:--- request header ---
# DEBUG:root:GET /ob/api/ws/TLB99029472/venues/NUEX/tickertape/stocks/NTU HTTP/1.1
# Upgrade: websocket
# Connection: Upgrade
# Host: api.stockfighter.io:443
# Origin: http://api.stockfighter.io:443
# Sec-WebSocket-Key: J0yQDV+LLSCr6e3fblk2kA==
# Sec-WebSocket-Version: 13
#
#
# DEBUG:root:-----------------------
# DEBUG:root:--- response header ---
# DEBUG:root:HTTP/1.1 101 Switching Protocols
# DEBUG:root:Server: nginx/1.8.0
# DEBUG:root:Date: Fri, 22 Jan 2016 20:49:10 GMT
# DEBUG:root:Connection: upgrade
# DEBUG:root:Upgrade: websocket
# DEBUG:root:Sec-WebSocket-Accept: ZzkecOgsLzBCVMtBraEV2HVZHZ8=
# DEBUG:root:-----------------------

# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,...">

# %%
a1, = ax.plot(navs, color="red")
a2, = ax.plot(nav_news, color="blue")
a3, = ax.plot(sell_orders, color="pink")
a4, = ax.plot(buy_orders, color="brown")

# %%
def update(i):
    ax.relim()

    ax.autoscale_view()
    
    a1.set_ydata(navs)
    a2.set_ydata(nav_news)
    a3.set_ydata(sell_orders)
    a4.set_ydata(buy_orders)

    return a1, a2, a3, a4

# %%
from matplotlib import animation

# %%
ani = animation.FuncAnimation(fig, update, interval=50, blit=True)

# %%
draw()

# %%
print 'a'
# Out:
# a
